# %% [markdown]
# # Importando Bibliotecas

# %%
import numpy as np
import random

# %% [markdown]
# # Gerando a tabela de distâncias

# %%
dists = np.zeros((6,6), dtype=int)
lim = 0 #criação da variável auxiliar
for i in range(0, dists.shape[0]):
    lim += 1
    j = 0
    while j < lim:
        if i != j:
            x = random.randint(1,100)
            dists[i][j] = x
            dists[j][i] = x
        j += 1
print(dists) 

#O array de 2 dimensões representa uma tabela de distâncias da maneira mais fidedigna possível, pois a posição i,j é a mesma que 
#j,i. E também se i e j estão na mesma posição, seu valor é 0.
# Out:
# [[ 0 26 14 22 35  5]
#  [26  0 88 14 69 26]
#  [14 88  0  1 82 84]
#  [22 14  1  0 13 70]
#  [35 69 82 13  0 28]
#  [ 5 26 84 70 28  0]]

# %% [markdown]
# Iniciando os indivíduos

# %%
num_individuos = 20
numeros = np.array([0,1,2,3,4,5,0])
populacao_inicial = np.zeros((num_individuos,len(numeros)),dtype=int)
for i in range (num_individuos):
    np.random.shuffle(numeros)
    populacao_inicial[i] = numeros

# %% [markdown]
# # Funções

# %% [markdown]
# Funções de Fitness

# %%
def fitness (ind):
    f = 0
    for x in range(len(ind)-1):
        i,j = ind[x],ind[x+1]
        f+= dists[i][j]
        
    if(ind[0]!=0):
        f+= 300
        
    if ind[len(ind)-1] != 0:
        f+= 300
        
    return 1200-f
        
def retorna_fitness(populacao):
    fit = []
    for i in range(num_individuos):
        f = fitness(populacao[i])
        fit.append(f)
    return fit

# %% [markdown]
# Torneio

# %%
def selecao_torneio(fitnesses):
    pai1 = -1
    pai2 = -1
    while pai1 == pai2:
        sorteados = random.sample(range(0, num_individuos), 2)
        if fitnesses[sorteados[0]] >= fitnesses[sorteados[1]]:
            pai1 = sorteados[0]
        else:
            pai1 = sorteados[1]

        sorteados = random.sample(range(0, num_individuos), 2)
        if fitnesses[sorteados[0]] > fitnesses[sorteados[1]]:
            pai2 = sorteados[0]
        else:
            pai2 = sorteados[1]  
        
    return pai1,pai2

# %%
def cruzamento(ids,populacao):
    numeros = np.array([0,1,2,3,4,5,0])
    ponto = random.randint(0, len(numeros)-0)
    pai1 = populacao[ids[0]]
    pai2 = populacao[ids[1]]
    
    filho1 = np.concatenate([pai1[:ponto],pai2[ponto:]])
    filho2 = np.concatenate([pai2[:ponto],pai1[ponto:]])

    if len(np.unique(filho1)) != 6: #verificando se existem 6 números únicos no indivíduo
        dif1 = np.setdiff1d(numeros, filho1)
        balancear(filho1,dif1)
    
    if len(np.unique(filho2)) != 6:
        dif2 = np.setdiff1d(numeros, filho2)
        balancear(filho2,dif2)
    
        
        
    return filho1,filho2

# %% [markdown]
# Essa função irá garantir que o array tenha valores diferentes, pois um indivíduo com valores repetidos é infactível.

# %%
def balancear(filho,dif):
    if (random.randint(0,100)) < 50:
        np.random.shuffle(dif)
    i = 0
    repetidos = []
    while len(dif) != 0:
        if filho[i] not in repetidos:
            repetidos.append(filho[i])
        else:
            filho[i] = dif[0]
            dif = np.delete(dif,0)
        i+= 1
    return filho

# %%
def mutacao(filhos,taxa):
    for i in range(len(filhos)):
        if random.random() < taxa:
            pos1 = random.randint(0,len(numeros)-1)
            pos2 = random.randint(0,len(numeros)-1)
            filhos[i][pos1],filhos[i][pos2] = filhos[i][pos2],filhos[i][pos1] #invertendo duas cidades dos filhos
            
        
    return filhos

# %%
def elitismo(fitnesses):

    id1 = fitnesses.index(max(fitnesses))

    fitnesses.pop(id1)
    id2 = fitnesses.index(max(fitnesses))

    return id1,id2

# %% [markdown]
# # Programa Principal

# %%
num_geracoes = 500

for it in range(num_geracoes):
    nova_populacao = np.zeros((num_individuos,len(numeros)), dtype=int)
    fit = retorna_fitness(populacao_inicial)
    id_melhor = fit.index(max(fit))

    print(f"Geração {it}. Melhor escolha: {populacao_inicial[id_melhor]}, Fitness: {fit[id_melhor]}")
    
    elite = elitismo(fit.copy()) 
    nova_populacao[0] = populacao_inicial[elite[0]]
    nova_populacao[1] = populacao_inicial[elite[1]]
    
    num_filhos = 2
    
    while num_filhos < num_individuos:

        ind_vencedores = selecao_torneio(fit)

        filhos = cruzamento(ind_vencedores,populacao_inicial)

        filhos = mutacao(filhos,0.5)

        nova_populacao[num_filhos] = filhos[0]
        nova_populacao[num_filhos+1] = filhos[1]

        num_filhos = num_filhos + 2

    populacao_inicial = nova_populacao.copy()
# Out:
# Geração 0. Melhor escolha: [2 3 4 1 0 5 0], Fitness: 781
# Geração 1. Melhor escolha: [0 4 3 2 1 5 0], Fitness: 1032
# Geração 2. Melhor escolha: [0 4 3 2 1 5 0], Fitness: 1032
# Geração 3. Melhor escolha: [0 4 3 2 1 5 0], Fitness: 1032
# Geração 4. Melhor escolha: [0 4 3 2 1 5 0], Fitness: 1032
# Geração 5. Melhor escolha: [0 4 3 2 1 5 0], Fitness: 1032
# Geração 6. Melhor escolha: [0 4 2 3 1 5 0], Fitness: 1037
# Geração 7. Melhor escolha: [0 2 3 4 1 5 0], Fitness: 1072
# Geração 8. Melhor escolha: [0 2 3 4 1 5 0], Fitness: 1072
# Geração 9. Melhor escolha: [0 2 3 4 1 5 0], Fitness: 1072
# Geração 10. Melhor escolha: [0 2 3 4 1 5 0], Fitness: 1072
# Geração 11. Melhor escolha: [0 2 3 4 1 5 0], Fitness: 1072
# Geração 12. Melhor escolha: [0 2 3 4 1 5 0], Fitness: 1072
# Geração 13. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 14. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 15. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 16. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 17. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 18. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 19. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 20. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 21. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 22. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 23. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 24. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 25. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 26. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 27. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 28. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 29. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 30. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 31. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 32. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 33. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 34. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 35. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 36. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 37. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 38. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 39. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 40. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 41. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 42. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 43. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 44. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 45. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 46. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 47. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 48. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 49. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 50. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 51. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 52. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 53. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 54. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 55. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 56. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 57. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 58. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 59. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 60. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 61. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 62. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 63. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 64. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 65. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 66. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 67. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 68. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 69. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 70. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 71. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 72. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 73. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 74. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 75. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 76. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 77. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 78. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 79. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 80. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 81. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 82. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 83. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 84. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 85. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 86. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 87. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 88. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 89. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 90. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 91. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 92. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 93. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 94. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 95. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 96. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 97. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 98. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 99. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 100. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 101. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 102. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 103. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 104. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 105. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 106. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 107. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 108. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 109. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 110. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 111. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 112. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 113. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 114. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 115. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 116. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 117. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração 118. Melhor escolha: [0 2 3 4 5 1 0], Fitness: 1092
# Geração